# %% [markdown]
# <a href="https://colab.research.google.com/github/claudiarem/Microeconomia/blob/main/CIndiferencia3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Microeconomía.
# ### Claudia Cristina Reyes Montes de Oca

# %% [markdown]
# Para la función de utilidad que representa las preferencias racionales de la forma,
# $$u(x,y) = \min\{2x-y,2y-x\}$$
# vamos a esbozar la gráfica de curva de indiferencia correspondiente a nivel de utilidad $\overline{u} = 10$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir la función de utilidad
def utilidad(x, y):
    return np.minimum(2*x - y, 2*y - x)

# Valores para el nivel de utilidad constante
u0 = 10

# Crear un espacio de valores para x y y
x = np.linspace(0, 40, 400)
y = np.linspace(0, 40, 400)
X, Y = np.meshgrid(x, y)

# Calcular los valores de la función de utilidad
Z = utilidad(X,Y)

# Graficar la curva de indiferencia para un nivel de utilidad U0
plt.contour(X, Y, Z, levels=[u0], colors='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'Curva de Indiferencia para u(x,y) = min(2x-y,2y-x) = {u0}')
plt.grid(True)
plt.show()

# %% [markdown]
# Donde las rectas del sistema de ecuaciones son:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Definir las funciones para las dos rectas
def recta1(x):
    return 2*x - 10  # Ecuación para 2x - y = 10

def recta2(x):
    return (10 + x ) / 2    # Ecuación para 2y - x = 10

# Crear valores de x para graficar
x_vals1 = np.linspace(0, 20, 400)
x_vals2 = np.linspace(0, 20, 400)

# Calcular los valores de y para cada recta
x_vals1_recta1 = recta1(x_vals1)
x_vals2_recta2 = recta2(x_vals2)

# Graficar las rectas
plt.plot(x_vals1, x_vals1_recta1, label=r'$2x - y = 10$', color='blue')
plt.plot(x_vals2, x_vals2_recta2, label=r'$2y - x = 10$', color='green')

#Graficar el punto de intersección (x,y)= (10/3,10/3)
plt.plot(10, 10, 'ro', label='Intersección')

# Añadir etiquetas y leyenda
plt.xlim(0, 20) #limites del eje x
plt.ylim(0, 20) #limites del eje y
plt.title(r'Gráfica de las ecuaciones $2x - y = 10$ y $2y - x = 10$')
plt.xlabel('x')
plt.ylabel('y')
plt.axhline(0, color='black',linewidth=0.5)
plt.axvline(0, color='black',linewidth=0.5)
plt.legend()

# Mostrar la cuadrícula y gráfico
plt.grid(True)
plt.show()
